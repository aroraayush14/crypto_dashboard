# %%
import requests


base_url = 'https://api.coingecko.com/api/v3'

# Example list of cryptos you hold and their amounts
crypto_holdings = {
    'Bitcoin': {'amount': 1.5, 'purchase_price': 50000},
    'Ethereum': {'amount': 0.0113886, 'purchase_price': 1790},
    # Add more cryptocurrencies and their amounts here
}

def get_crypto_price(coin_id):
    url = f"{base_url}/simple/price?ids={coin_id}&vs_currencies=usd"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data[coin_id]['usd']
    else:
        return None

def calculate_profit_loss(amount, purchase_price, current_price):
    invested_amount = amount * purchase_price
    current_value = amount * current_price
    pnl = current_value - invested_amount
    return pnl

with open('crypto_holdings.txt', 'w') as file:
    for crypto, details in crypto_holdings.items():
        price = get_crypto_price(crypto.lower())
        if price:
            current_price = float(price)
            pnl = calculate_profit_loss(details['amount'], details['purchase_price'], current_price)
            file.write(f"Crypto: {crypto}\n")
            file.write(f"Amount: {details['amount']}\n")
            file.write(f"Purchase Price: ${details['purchase_price']}\n")
            file.write(f"Current Price: ${current_price}\n")
            file.write(f"Net PnL: ${pnl}\n")
            file.write("=====================\n")

print("Data written to crypto_holdings.txt")
# Out:
# Data written to crypto_holdings.txt

# %%
print(data)
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 36476, 'market_cap': 712920216730, 'market_cap_rank': 1, 'fully_diluted_valuation': 765819920632, 'total_volume': 23367184363, 'high_24h': 37444, 'low_24h': 35788, 'price_change_24h': -965.0966825130381, 'price_change_percentage_24h': -2.57761, 'market_cap_change_24h': -19437197268.16101, 'market_cap_change_percentage_24h': -2.65406, 'circulating_supply': 19549406.0, 'total_supply': 21000000.0, 'max_supply': 21000000.0, 'ath': 69045, 'ath_change_percentage': -47.17757, 'ath_date': '2021-11-10T14:24:11.849Z', 'atl': 67.81, 'atl_change_percentage': 53685.08342, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2023-11-22T04:47:14.636Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 1988.42, 'market_cap': 238946937186, 'market_cap_rank': 2, 'fully_diluted_valuation': 238942991366, 'total_volume': 22393372202, 'high_24h': 2018.93, 'low_24h': 1940.08, 'price_change_24h': -27.86410446560876, 'price_change_percentage_24h': -1.38196, 'market_cap_change_24h': -3657564481.929016, 'market_cap_change_percentage_24h': -1.50762, 'circulating_supply': 120251000.411085, 'total_supply': 120249014.661258, 'max_supply': None, 'ath': 4878.26, 'ath_change_percentage': -59.22794, 'ath_date': '2021-11-10T14:24:19.604Z', 'atl': 0.432979, 'atl_change_percentage': 459268.20317, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 71.89455230190117, 'currency': 'btc', 'percentage': 7189.455230190117}, 'last_updated': '2023-11-22T04:47:07.436Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://assets.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'current_price': 1.0, 'market_cap': 88418828302, 'market_cap_rank': 3, 'fully_diluted_valuation': 88418828302, 'total_volume': 47425507979, 'high_24h': 1.005, 'low_24h': 0.995896, 'price_change_24h': -0.000121377606579154, 'price_change_percentage_24h': -0.01213, 'market_cap_change_24h': 358589819, 'market_cap_change_percentage_24h': 0.40721, 'circulating_supply': 88308652878.7212, 'total_supply': 88308652878.7212, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.32536, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 74.884, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2023-11-22T04:45:00.361Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'BNB', 'image': 'https://assets.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970', 'current_price': 235.59, 'market_cap': 36142975056, 'market_cap_rank': 4, 'fully_diluted_valuation': 36142975056, 'total_volume': 3592947095, 'high_24h': 264.57, 'low_24h': 224.85, 'price_change_24h': -26.643367213952956, 'price_change_percentage_24h': -10.16035, 'market_cap_change_24h': -4244140988.3065567, 'market_cap_change_percentage_24h': -10.50865, 'circulating_supply': 153856150.0, 'total_supply': 153856150.0, 'max_supply': 200000000.0, 'ath': 686.31, 'ath_change_percentage': -65.77126, 'ath_date': '2021-05-10T07:24:17.097Z', 'atl': 0.0398177, 'atl_change_percentage': 589874.03395, 'atl_date': '2017-10-19T00:00:00.000Z', 'roi': None, 'last_updated': '2023-11-22T04:47:17.767Z'}, {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP', 'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442', 'current_price': 0.593736, 'market_cap': 31887466014, 'market_cap_rank': 5, 'fully_diluted_valuation': 59353528377, 'total_volume': 1446543138, 'high_24h': 0.616056, 'low_24h': 0.580049, 'price_change_24h': -0.0200361609197095, 'price_change_percentage_24h': -3.26443, 'market_cap_change_24h': -1181059636.3127747, 'market_cap_change_percentage_24h': -3.57155, 'circulating_supply': 53718306475.0, 'total_supply': 99988221902.0, 'max_supply': 100000000000.0 ...
